# %%
import pandas as pd

# %%
suffixes_to_remove = ["?fbclid=", "+&", "?_x_tr_", "?back="]
search_cache_identifier = "/search?q=cache:"
sacommunity_url = "https://sacommunity.org"

# %%
def clean_landing_page_column(text: str) -> str:
    if search_cache_identifier in text:
        text = text[text.index(sacommunity_url):].replace(sacommunity_url, "")

    for suffix_to_remove in suffixes_to_remove:
        if suffix_to_remove in text:
            text = text[:text.index(suffix_to_remove)]

    # remove underscore
    text = text.replace("_", " ")
    # remove /org/
    text = text.replace("/org/", "")

    return text

def get_organization_id(text: str) -> str:
    if "-" in text:
        return int(text[:text.index("-")])
    else:
        return None
    
def get_organization_name(text: str) -> str:
    if "-" in text:
        return text[text.index("-") + 1:]
    else:
        return None

# test texts
inputs = [
    "/org/196236-Dave's_Angels_Playgroup?fbclid=IwAR05WAQ0z5mwY7v1UEVmkDITFg7sDh8pcD8taJ3oGH4336EpkNZeP81BIKc",
    "/search?q=cache:UTs_a-1ZNgEJ:https://sacommunity.org/org/196341-Neighbourhood_Watch_-_Linden_Park_249+&cd=63&hl=en&ct=clnk&gl=bj",
    "/org/201669-Gifted_&_Talented_Children's_Association_of_SA_Inc.?_x_tr_sl=en&_x_tr_tl=th&_x_tr_hl=th&_x_tr_pto=sc",
    "/org/201830-Aged_Rights_Advocacy_Service_Inc.?back=https://www.google.com/search?client=safari&as_qdr=all&as_occt=any&safe=active&as_q=Age+advocate+for+South+Australia&channel=aplab&source=a-app1&hl=en",
    "/org/201950-SA_Ambulance_Service?_x_tr_sl=en&_x_tr_tl=fr&_x_tr_hl=fr&_x_tr_pto=nui,sc"
]
for input in inputs:
    print(clean_landing_page_column(input))
# Out:
# 196236-Dave's Angels Playgroup
# 196341-Neighbourhood Watch - Linden Park 249
# 201669-Gifted & Talented Children's Association of SA Inc.
# 201830-Aged Rights Advocacy Service Inc.
# 201950-SA Ambulance Service

# %%
landing_page_file_path = './data/Burnside Council Landing page 2021-2022.xlsx'
df_google_analytics = pd.read_excel(landing_page_file_path, sheet_name='Dataset1')
df_google_analytics
# Out:
# /Users/pujanmaharjan/anaconda/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     Custom Variable (Value 01)  \
# 0                     0QK91R12
# 1                     0QK91R12
# 2                     0QK91R12
# 3                     0QK91R12
# 4                     0QK91R12
# ..                         ...
# 234                   0QK91R12
# 235                   0QK91R12
# 236                   0QK91R12
# 237                   0QK91R12
# 238                        NaN
#
#                                           Landing Page  Sessions  \
# 0        /org/201829-Cats_Assistance_To_Sterilise_Inc.       632
# 1    /org/202703-Drug_and_Alcohol_Services_SA_-_Wit...       295
# 2    /org/236722-Justices_of_the_Peace_-_City_of_Bu...       237
# 3                     /org/201950-SA_Ambulance_Service       234
# 4                       /org/201612-Dementia_Australia       214
# ..                                                 ...       ...
# 234                   /org/234010-MatchWorks_-_Tusmore         1
# 235              /org/235748-Rostrum_Club_32_-_Tusmore         1
# 236              /org/236332-Gentle_Touch_Orthodontics         1
# 237  /search?q=cache:UTs_a-1ZNgEJ:https://sacommuni...         1
# 238                                                NaN      6964
#
#      % New Sessions  New Users  Bounce Rate  Pages / Session  \
# 0          0.829114        524     0.794304         1.229430
# 1          0.762712        225     0.755932         1.223729
# 2          0.898734        213     0.869198         1.071730
# 3          0.871795        204     0.705128         1.376068
# 4          0.827103        177     0.836449         1.140187
# ..              ...        ...          ...              ...
# 234        0.000000          0     1.000000         1.000000
# 235        0.000000          0     1.000000         1.000000
# 236        1.000000          1     1.000000         1.000000
# 237        1.000000          1     1.000000         1.000000
# 238        0.800402       5574     0.803418         1.779868
#
#      Avg. Session Duration  Goal Conversion Rate  Goal Completions  Goal Value
# 0                49.006329                     0                 0           0
# 1                82.186441                     0                 0           0
# 2                35.308017                     0                 0           0
# 3                64.128205                     0                 0           0
# 4                38.948598                     0                 0           0
# ..                     ...                   ...               ...         ...
# 234               0.000000                     0                 0           0
# 235               0.000000                     0                 0           0
# 236               0.000000                     0                 0           0
# 237               0.000000                     0                 0           0
# 238              59.364877                     0                 0           0
#
# [239 rows x 11 columns]

# %%
def clean_google_analytics_file(df_ga_orig: pd.DataFrame) -> pd.DataFrame:
    df_ga = df_ga_orig.dropna().copy()
    df_ga['organization_id_name'] = df_ga['Landing Page'].apply(clean_landing_page_column)
    df_ga['organization_id'] = df_ga['organization_id_name'].apply(get_organization_id)
    df_ga['organization_name'] = df_ga['organization_id_name'].apply(get_organization_name)
    return df_ga[["Landing Page", "organization_id_name","organization_id","organization_name", "Sessions"]]

# %%
df_cleaned = clean_google_analytics_file(df_google_analytics)
df_cleaned
# Out:
#                                           Landing Page  \
# 0        /org/201829-Cats_Assistance_To_Sterilise_Inc.
# 1    /org/202703-Drug_and_Alcohol_Services_SA_-_Wit...
# 2    /org/236722-Justices_of_the_Peace_-_City_of_Bu...
# 3                     /org/201950-SA_Ambulance_Service
# 4                       /org/201612-Dementia_Australia
# ..                                                 ...
# 233  /org/231232-SA_Metropolitan_Fire_Service_-_Beu...
# 234                   /org/234010-MatchWorks_-_Tusmore
# 235              /org/235748-Rostrum_Club_32_-_Tusmore
# 236              /org/236332-Gentle_Touch_Orthodontics
# 237  /search?q=cache:UTs_a-1ZNgEJ:https://sacommuni...
#
#                                   organization_id_name  organization_id  \
# 0             201829-Cats Assistance To Sterilise Inc.           201829
# 1    202703-Drug and Alcohol Services SA - Withdraw...           202703
# 2      236722-Justices of the Peace - City of Burnside           236722
# 3                          201950-SA Ambulance Service           201950
# 4                            201612-Dementia Australia           201612
# ..                                                 ...              ...
# 233  231232-SA Metropolitan Fire Service - Beulah Park           231232
# 234                        234010-MatchWorks - Tusmore           234010
# 235                   235748-Rostrum Club 32 - Tusmore           235748
# 236                   236332-Gentle Touch Orthodontics           236332
# 237       196341-Neighbourhood Watch - Linden Park 249           196341
#
#                                      organization_name  Sessions
# 0                    Cats Assistance To Sterilise Inc.       632
# 1    Drug and Alcohol Services SA - Withdrawal Serv...       295
# 2             Justices of the Peace - City of Burnside       237
# 3                                 SA Ambulance Service       234
# 4                                   Dementia Australia       214
# ..                                                 ...       ...
# 233         SA Metropolitan Fire Service - Beulah Park         1
# 234                               MatchWorks - Tusmore         1
# 235                          Rostrum Club 32 - Tusmore         1
# 236                          Gentle Touch Orthodontics         1
# 237              Neighbourhood Watch - Linden Park 249         1
#
# [238 rows x 5 columns]

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238 entries, 0 to 237
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Landing Page          238 non-null    object
#  1   organization_id_name  238 non-null    object
#  2   organization_id       238 non-null    int64
#  3   organization_name     238 non-null    object
#  4   Sessions              238 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 11.2+ KB

# %%
df_cleaned[df_cleaned['organization_id'] == 196236]
# Out:
#                                           Landing Page  \
# 40                 /org/196236-Dave's_Angels_Playgroup
# 201  /org/196236-Dave's_Angels_Playgroup?fbclid=IwA...
# 202  /org/196236-Dave's_Angels_Playgroup?fbclid=IwA...
# 203  /org/196236-Dave's_Angels_Playgroup?fbclid=IwA...
# 204  /org/196236-Dave's_Angels_Playgroup?fbclid=IwA...
# 205  /org/196236-Dave's_Angels_Playgroup?fbclid=IwA...
# 206  /org/196236-Dave's_Angels_Playgroup?fbclid=IwA...
# 207  /org/196236-Dave's_Angels_Playgroup?fbclid=IwA...
# 208  /org/196236-Dave's_Angels_Playgroup?fbclid=IwA...
# 209  /org/196236-Dave's_Angels_Playgroup?fbclid=IwA...
# 210  /org/196236-Dave's_Angels_Playgroup?fbclid=IwA...
#
#                organization_id_name  organization_id        organization_name  \
# 40   196236-Dave's Angels Playgroup           196236  Dave's Angels Playgroup
# 201  196236-Dave's Angels Playgroup           196236  Dave's Angels Playgroup
# 202  196236-Dave's Angels Playgroup           196236  Dave's Angels Playgroup
# 203  196236-Dave's Angels Playgroup           196236  Dave's Angels Playgroup
# 204  196236-Dave's Angels Playgroup           196236  Dave's Angels Playgroup
# 205  196236-Dave's Angels Playgroup           196236  Dave's Angels Playgroup
# 206  196236-Dave's Angels Playgroup           196236  Dave's Angels Playgroup
# 207  196236-Dave's Angels Playgroup           196236  Dave's Angels Playgroup
# 208  196236-Dave's Angels Playgroup           196236  Dave's Angels Playgroup
# 209  196236-Dave's Angels Playgroup           196236  Dave's Angels Playgroup
# 210  196236-Dave's Angels Playgroup           196236  Dave's Angels Playgroup
#
#      Sessions
# 40         41
# 201         1
# 202         1
# 203         1
# 204         1
# 205         1
# 206         1
# 207         1
# 208         1
# 209         1
# 210         1

# %%
def grp_by_org_id_and_sum_sessions(df_cleaned: pd.DataFrame) -> pd.DataFrame:
    df_grp_org_id = df_cleaned.groupby(by=['organization_id']).sum("Sessions")
    # df_grp_org_id = df_grp_org_id.reset_index()
    return df_grp_org_id

# %%
df_grp_by_org_id = grp_by_org_id_and_sum_sessions(df_cleaned)
df_grp_by_org_id
# Out:
#                  Sessions
# organization_id
# 194813                 34
# 196167                 11
# 196171                 30
# 196173                  4
# 196174                  4
# ...                   ...
# 236280                 58
# 236332                  1
# 236722                237
# 237283                  7
# 237449                  5
#
# [205 rows x 1 columns]

# %%
df_grp_by_org_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 194813 to 237449
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sessions  205 non-null    int64
# dtypes: int64(1)
# memory usage: 3.2 KB

# %%
df_grp_by_org_id[df_grp_by_org_id.index == 194813]
# Out:
#                  Sessions
# organization_id
# 194813                 34

# %%
df_grp_by_org_id[df_grp_by_org_id.index == 1948132].values
# Out:
# array([], shape=(0, 1), dtype=int64)

# %%
len(df_grp_by_org_id[df_grp_by_org_id.index == 194813].values)
# Out:
# 1

# %%
df_grp_by_org_id[df_grp_by_org_id.index == 194813].values[0][0]
# Out:
# 34

# %%
df_grp_by_org_id.sort_values(by=["organization_id"]).head(80)
# Out:
#     organization_id  Sessions
# 0            194813        34
# 1            196167        11
# 2            196171        30
# 3            196173         4
# 4            196174         4
# ..              ...       ...
# 75           196326         5
# 76           196337        11
# 77           196340         4
# 78           196341         1
# 79           196342        22
#
# [80 rows x 2 columns]

# %%
# for all the duplicates get data from sa community export
# easy solution, get all organization name from sacommunity exports

# %%
df_sacommunity_data = pd.read_csv('./data/Burnside Council-cu_export_2023-08-16_Data.Gov.au_export.csv')
df_sacommunity_data
# Out:
#       ID_19                                           Org_name  \
# 0    194023                  Motorcycling South Australia Inc.
# 1    194025                                    Orienteering SA
# 2    194813             Burnside Library & Information Service
# 3    196167                             Burnside Family Church
# 4    196171            Linden Park Primary School and OSHC/VAC
# ..      ...                                                ...
# 209  237283                 Salvos Stores - Kensington Gardens
# 210  237449   Military and Emergency Services Health Australia
# 211  238110  South Australian Chinese Community Language Sc...
# 212  238198    Resthaven Leabrook Retirement Living Apartments
# 213  238313                              Glenunga Cricket Club
#
#                               Street_Address_Line_1 Street_Address_Line_2  \
# 0    Motorcycling South Australia Inc., 251 The Pde                   NaN
# 1                                               NaN                   NaN
# 2                                  401 Greenhill Rd                   NaN
# 3                                    88 Lockwood Rd                   NaN
# 4             Linden Park Primary School, 14 Hay Rd                   NaN
# ..                                              ...                   ...
# 209                                   418 Magill Rd                   NaN
# 210                           Jamie Larcombe Centre         Eucalyptus Ln
# 211                                             NaN       384 Portrush Rd
# 212                             334 Kensington Road                   NaN
# 213                             70 Conyngham Street                   NaN
#
#                  Suburb            State  Postal_Code    Country  \
# 0           Beulah Park  South Australia       5067.0  Australia
# 1              Glenside  South Australia       5065.0  Australia
# 2               Tusmore  South Australia       5065.0  Australia
# 3              Burnside  South Australia       5066.0  Australia
# 4           Linden Park  South Australia       5065.0  Australia
# ..                  ...              ...          ...        ...
# 209  Kensington Gardens  South Australia       5068.0  Australia
# 210            Glenside  South Australia       5056.0  Australia
# 211             Tusmore  South Australia       5065.0  Australia
# 212     Kensington Park  South Australia       5068.0  Australia
# 213            Glenunga  South Australia       5064.0  Australia
#
#       Postal_Address_Line_1 Postal_Address_Line_2  ...  \
# 0                       NaN                   NaN  ...
# 1        c/o 5/355 Angas St                   NaN  ...
# 2                  PO Box 9                   NaN  ...
# 3                       NaN                   NaN  ...
# 4                       NaN                   NaN  ...
# ..                      ...                   ...  ...
# 209                     NaN                   NaN  ...
# 210  THRF Group Head Office             PO Box 77  ...
# 211         384 Portrush Rd                   NaN  ...
# 212                     NaN                   NaN  ...
# 213                     NaN                   NaN  ...
#
#                                 Organisati_Eligibility  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 209                                                NaN
# 210  Current and former serving Australian military...
# 211                                                NaN
# 212  Eligibility for retirement unit or apartment r...
# 213                                                NaN
#
#                                    Organisati_Services  \
# 0    Coordination and promotion of motorcycle sport...
# 1    Coordination and promotion of orienteering in ...
# 2    Public library\r\nHome Energy Toolkit availabl...
# 3    Sunday Service 10am\r\nFri night kid's club an...
# 4    Primary education - Reception to Year 7\r\nOut...
# ..                                                 ...
# 209  Clothing\r\nBric-a-Brac & Homewares\r\nBooks, ...
# 210  Research Institute\r\nOffers research-based pr...
# 211    Chinese language learning  and cultural classes
# 212  8 retirement living apartments  \r\ntwo or thr...
# 213                                            Cricket
#
#      Organisation_Created_Date Organisation_Last_updated  \
# 0          2009-11-23 21:44:28       2022-11-16 11:54:08
# 1          2009-11-23 21:44:28       2022-07-24 15:14:31
# 2          2009-11-23 21:44:58       2022-12-07 10:38:10
# 3          2009-11-23 21:45:53       2023-01-25 13:53:04
# 4          2009-11-23 21:45:53       2023-01-25 14:06:43
# ..                         ...                       ...
# 209        2021-08-11 13:53:47       2021-08-24 13:57:38
# 210        2021-10-25 12:15:00       2022-11-29 22:42:28
# 211        2023-02-02 20:10:20       2023-04-03 11:41:22
# 212        2023-03-30 13:37:02       2023-03-31 17:06:40
# 213        2023-06-01 10:29:44       2023-06-05 09:31:13
#
#                                       IM_Screen_Name_1  \
# 0           https://www.facebook.com/motorcyclingsa/ 7
# 1            https://www.facebook.com/OrienteeringSA 7
# 2                                    BurnsideLibrary 7
# 3                               burnsidefamilychurch 7
# 4    https://www.facebook.com/groups/3219860600/abo...
# ..                                                 ...
# 209  https://www.facebook.com/TheSalvationArmySouth...
# 210                                                NaN
# 211                                                NaN
# 212                                     resthaven.sa 7
# 213                              glenungacricketclub 7
#
#                                       IM_Screen_Name_2   IM_Screen_Name_3  \
# 0                                                  NaN                NaN
# 1    https://www.youtube.com/channel/UCSrZVpB1et3Jo...                NaN
# 2                                    BurnsideLibrary 4  burnsidelibrary 1
# 3                                      BFamilyChurch 4                NaN
# 4                                                  NaN                NaN
# ..                                                 ...                ...
# 209                                                NaN                NaN
# 210                                                NaN                NaN
# 211                                                NaN                NaN
# 212                                     Resthaven_SA 4    resthaveninc 12
# 213                             glenungacricketclub 12                NaN
#
#               IM_Screen_Name_4  IM_Screen_Name_5 IM_Screen_Name_6
# 0                          NaN               NaN              NaN
# 1                          NaN               NaN              NaN
# 2                          NaN               NaN              NaN
# 3                          NaN               NaN              NaN
# 4                          NaN               NaN              NaN
# ..                         ...               ...              ...
# 209                        NaN               NaN              NaN
# 210                        NaN               NaN              NaN
# 211                        NaN               NaN              NaN
# 212  resthaven-incorporated 11    ResthavenInc 1              NaN
# 213                        NaN               NaN              NaN
#
# [214 rows x 56 columns]

# %%
df_sacommunity_data[df_sacommunity_data['ID_19'] == 196294]

# %%
df_sacommunity_data.columns
# Out:
# Index(['ID_19', 'Org_name', 'Street_Address_Line_1', 'Street_Address_Line_2',
#        'Suburb', 'State', 'Postal_Code', 'Country', 'Postal_Address_Line_1',
#        'Postal_Address_Line_2', 'Suburb.1', 'State.1', 'Postal_Code.1',
#        'Country.1', 'Organisati_Hours', 'Organisati_Meetings',
#        'Organisati_AGM', 'Geo_Code_1_StreetAddress_',
#        'Geo_Code_2_StreetAddress_', 'Organisati_Venue_hire',
#        'Organisati_Access', 'Organisati_Disability_parking',
#        'Organisati_Access_toilets', 'Organisati_Wheelchair_access',
#        'Organisati_Fees', 'Organisati_ABN', 'Contact', 'Phone_1',
#        'Phone_1_comment', 'Phone_2', 'Phone_2_comment', 'Phone_3',
#        'Phone_3_comment', 'Email_1', 'Email_2', 'Email_3', 'Email_4',
#        'Website_1', 'Website_2', 'Website_3', 'Primary_Category',
#        'Directory_Directory_Entry_1', 'Directory_Directory_Entry_2',
#        'Directory_Directory_Entry_3', 'Parent_Body', 'Organisati_Tag_Line',
#        'Organisati_Eligibility', 'Organisati_Services',
#        'Organisation_Created_Date', 'Organisation_Last_updated',
#        'IM_Screen_Name_1', 'IM_Screen_Name_2', 'IM_Screen_Name_3',
#        'IM_Screen_Name_4', 'IM_Screen_Name_5', 'IM_Screen_Name_6'],
#       dtype='object')

# %%
df_sacommunity_data[['ID_19', 'Org_name', 'Primary_Category']]
# Out:
#       ID_19                                           Org_name  \
# 0    194023                  Motorcycling South Australia Inc.
# 1    194025                                    Orienteering SA
# 2    194813             Burnside Library & Information Service
# 3    196167                             Burnside Family Church
# 4    196171            Linden Park Primary School and OSHC/VAC
# ..      ...                                                ...
# 209  237283                 Salvos Stores - Kensington Gardens
# 210  237449   Military and Emergency Services Health Australia
# 211  238110  South Australian Chinese Community Language Sc...
# 212  238198    Resthaven Leabrook Retirement Living Apartments
# 213  238313                              Glenunga Cricket Club
#
#                          Primary_Category
# 0                              Recreation
# 1                              Recreation
# 2    Communication & Information Services
# 3                Religions & Philosophies
# 4                               Education
# ..                                    ...
# 209            Material & Practical Needs
# 210                   Health & Disability
# 211                             Education
# 212                         Accommodation
# 213                            Recreation
#
# [214 rows x 3 columns]
