# %%
# 1. Import necessary libraries
import pandas as pd
import os

# %%
# 2. Read data: google analytics and sacommunity export
DATA_ROOT_FOLDER = './data'

def get_data_folder_path(council_name, fiscal_year):
    return os.path.join(DATA_ROOT_FOLDER, council_name, fiscal_year)

def get_google_analytics_landing_page_file_path(council_name, fiscal_year):
    data_folder_path = get_data_folder_path(council_name, fiscal_year)
    landing_page_file_name = 'google_analytics_landing_page.xlsx'   
    return os.path.join(data_folder_path, landing_page_file_name)

def get_sacommunity_data_gov_au_export_file_path(council_name, fiscal_year):
    data_folder_path = get_data_folder_path(council_name, fiscal_year)
    return os.path.join(data_folder_path, 'sacommunity_data_gov_au_export.csv')

def read_google_analytics_landing_page_data(file_path):
    return pd.read_excel(file_path, sheet_name='Dataset1')

def read_sacommunity_data_gov_au_export(file_path):
    return pd.read_csv(file_path)

# %%
COUNCIL = 'Burnside'
FISCAL_YEAR = '2022-2023'
google_analytics_landing_page_file_path = get_google_analytics_landing_page_file_path(COUNCIL, FISCAL_YEAR)
print('Google Analytics Landing page file path is ', google_analytics_landing_page_file_path)

sa_community_data_gov_au_export_file_path = get_sacommunity_data_gov_au_export_file_path(COUNCIL, FISCAL_YEAR)
print('SAcommunity data gov au export file path is ', sa_community_data_gov_au_export_file_path)
# Out:
# Google Analytics Landing page file path is  ./data/Burnside/2022-2023/google_analytics_landing_page.xlsx
# SAcommunity data gov au export file path is  ./data/Burnside/2022-2023/sacommunity_data_gov_au_export.csv

# %%
# google analytics data
google_analytics_landing_page_df = read_google_analytics_landing_page_data(google_analytics_landing_page_file_path)
google_analytics_landing_page_df.head()
# Out:
# /Users/pujanmaharjan/anaconda/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#   Custom Variable (Value 01)  \
# 0                   0QK91R12
# 1                   0QK91R12
# 2                   0QK91R12
# 3                   0QK91R12
# 4                   0QK91R12
#
#                                         Landing Page  Sessions  \
# 0      /org/201829-Cats_Assistance_To_Sterilise_Inc.       514
# 1                   /org/201950-SA_Ambulance_Service       319
# 2                     /org/201612-Dementia_Australia       271
# 3  /org/202703-Drug_and_Alcohol_Services_SA_-_Wit...       271
# 4       /org/236722-Justices_of_the_Peace_-_Burnside       265
#
#    % New Sessions  New Users  Bounce Rate  Pages / Session  \
# 0        0.859922        442     0.809339         1.161479
# 1        0.884013        282     0.793103         1.150470
# 2        0.797048        216     0.892989         1.077491
# 3        0.782288        212     0.819188         1.140221
# 4        0.875472        232     0.867925         1.079245
#
#    Avg. Session Duration  Goal Conversion Rate  Goal Completions  Goal Value
# 0              41.268482                     0                 0           0
# 1              20.442006                     0                 0           0
# 2              36.151292                     0                 0           0
# 3              38.811808                     0                 0           0
# 4              24.573585                     0                 0           0

# %%
# SAcommunity data
sa_community_data_gov_au_export_df = read_sacommunity_data_gov_au_export(sa_community_data_gov_au_export_file_path)
sa_community_data_gov_au_export_df.head()
# Out:
#     ID_19                                 Org_name  \
# 0  194023        Motorcycling South Australia Inc.
# 1  194025                          Orienteering SA
# 2  194813   Burnside Library & Information Service
# 3  196167                   Burnside Family Church
# 4  196171  Linden Park Primary School and OSHC/VAC
#
#                             Street_Address_Line_1 Street_Address_Line_2  \
# 0  Motorcycling South Australia Inc., 251 The Pde                   NaN
# 1                                             NaN                   NaN
# 2                                401 Greenhill Rd                   NaN
# 3                                  88 Lockwood Rd                   NaN
# 4           Linden Park Primary School, 14 Hay Rd                   NaN
#
#         Suburb            State  Postal_Code    Country Postal_Address_Line_1  \
# 0  Beulah Park  South Australia       5067.0  Australia                   NaN
# 1     Glenside  South Australia       5065.0  Australia    c/o 5/355 Angas St
# 2      Tusmore  South Australia       5065.0  Australia              PO Box 9
# 3     Burnside  South Australia       5066.0  Australia                   NaN
# 4  Linden Park  South Australia       5065.0  Australia                   NaN
#
#   Postal_Address_Line_2  ... Organisation_Last_updated  \
# 0                   NaN  ...       2022-11-16 11:54:08
# 1                   NaN  ...       2022-07-24 15:14:31
# 2                   NaN  ...       2022-12-07 10:38:10
# 3                   NaN  ...       2023-01-25 13:53:04
# 4                   NaN  ...       2023-01-25 14:06:43
#
#                                     IM_Screen_Name_1  \
# 0         https://www.facebook.com/motorcyclingsa/ 7
# 1          https://www.facebook.com/OrienteeringSA 7
# 2                                  BurnsideLibrary 7
# 3                             burnsidefamilychurch 7
# 4  https://www.facebook.com/groups/3219860600/abo...
#
#                                     IM_Screen_Name_2   IM_Screen_Name_3  \
# 0                                                NaN                NaN
# 1  https://www.youtube.com/channel/UCSrZVpB1et3Jo...                NaN
# 2                                  BurnsideLibrary 4  burnsidelibrary 1
# 3                                    BFamilyChurch 4                NaN
# 4                                                NaN                NaN
#
#   IM_Screen_Name_4 IM_Screen_Name_5  IM_Screen_Name_6  Organisati_Council  \
# 0              NaN              NaN               NaN    City of Burnside
# 1              NaN              NaN               NaN    City of Burnside
# 2              NaN              NaN               NaN    City of Burnside
# 3              NaN              NaN               NaN    City of Burnside
# 4              NaN              NaN               NaN    City of Burnside
#
#    Organisati_Electorate_State_ Organisati_Electorate_Federal_
# 0                       Dunstan                          Sturt
# 1                         Bragg                          Sturt
# 2                         Bragg                          Sturt
# 3                         Bragg                          Sturt
# 4                         Bragg                          Sturt
#
# [5 rows x 59 columns]

# %%
# google analytics data cleanup

class GoogleAnalyticsDataProcessing():
    def __init__(self) -> None:
        self.suffixes_to_remove = ["?fbclid=", "+&", "?_x_tr_", "?back="]
        self.search_cache_identifier = "/search?q=cache:"
        self.sacommunity_url = "https://sacommunity.org"

    def clean_landing_page(self, text: str) -> str:
        if self.search_cache_identifier in text:
            text = text[text.index(self.sacommunity_url):].replace(self.sacommunity_url, "")

        for suffix_to_remove in self.suffixes_to_remove:
            if suffix_to_remove in text:
                text = text[:text.index(suffix_to_remove)]

        # remove underscore
        text = text.replace("_", " ")
        # remove /org/
        text = text.replace("/org/", "")

        return text.strip()

    def get_organization_id(self, text: str) -> str:
        if "-" in text:
            return int(text[:text.index("-")])
        else:
            return None
    
    def get_organization_name(self, text: str) -> str:
        if "-" in text:
            return text[text.index("-") + 1:]
        else:
            return None
        
    def get_sessions_by_organization(self, df_ga_orig: pd.DataFrame) -> pd.DataFrame:
        df_ga = df_ga_orig.dropna().copy()
        df_ga['organization_id_name'] = df_ga['Landing Page'].apply(self.clean_landing_page)
        df_ga['organization_id'] = df_ga['organization_id_name'].apply(self.get_organization_id)
        df_ga['organization_name'] = df_ga['organization_id_name'].apply(self.get_organization_name)
        return df_ga[["Landing Page", "organization_id_name", "organization_id", "organization_name", "Sessions"]]
    
    def group_sessions_by_organization(self, google_analytics_cleaned_df):
        return google_analytics_cleaned_df.groupby(by=['organization_id']).sum("Sessions")

    def join_sa_community_data_for_org_name(self, google_analytics_df, sa_community_df):
        results = []
        sessions_by_organization_id_df = self.group_sessions_by_organization(google_analytics_df)
        for index, row in sessions_by_organization_id_df.iterrows():
            org_id = index
            
            session_count = row["Sessions"]
            
            # organization name from sa-community file
            org_names_sa_community = sa_community_df[sa_community_df['ID_19'] == org_id]["Org_name"].values
            organization_name_sa_community = ''
            is_record_available_in_sacommunity_db = False
            if len(org_names_sa_community) > 0:
                organization_name_sa_community = org_names_sa_community[0]
                is_record_available_in_sacommunity_db = True
        
            # organization name from google analytics file
            org_names_google = google_analytics_df[google_analytics_df["organization_id"] == org_id]["organization_name"].values
            organization_name_google = ''
            if len(org_names_google) > 0:
                organization_name_google = org_names_google[0]

            landing_page = self.sacommunity_url + google_analytics_df[google_analytics_df["organization_id"] == org_id]["Landing Page"].values[0]
            results.append({
                'org_id': org_id,
                'landing_page': landing_page,
                'sessions_count': session_count,
                'organization_name_sa_community': organization_name_sa_community,
                'organization_name_google': organization_name_google,
                'is_record_available_in_sacommunity_db': is_record_available_in_sacommunity_db,
            })

        return pd.DataFrame(results)

# test texts
google_analytics_processing = GoogleAnalyticsDataProcessing()
inputs = [
    "/org/196236-Dave's_Angels_Playgroup?fbclid=IwAR05WAQ0z5mwY7v1UEVmkDITFg7sDh8pcD8taJ3oGH4336EpkNZeP81BIKc",
    "/search?q=cache:UTs_a-1ZNgEJ:https://sacommunity.org/org/196341-Neighbourhood_Watch_-_Linden_Park_249+&cd=63&hl=en&ct=clnk&gl=bj",
    "/org/201669-Gifted_&_Talented_Children's_Association_of_SA_Inc.?_x_tr_sl=en&_x_tr_tl=th&_x_tr_hl=th&_x_tr_pto=sc",
    "/org/201830-Aged_Rights_Advocacy_Service_Inc.?back=https://www.google.com/search?client=safari&as_qdr=all&as_occt=any&safe=active&as_q=Age+advocate+for+South+Australia&channel=aplab&source=a-app1&hl=en",
    "/org/201950-SA_Ambulance_Service?_x_tr_sl=en&_x_tr_tl=fr&_x_tr_hl=fr&_x_tr_pto=nui,sc"
]

for input in inputs:
    print(google_analytics_processing.clean_landing_page(input))
# Out:
# 196236-Dave's Angels Playgroup
# 196341-Neighbourhood Watch - Linden Park 249
# 201669-Gifted & Talented Children's Association of SA Inc.
# 201830-Aged Rights Advocacy Service Inc.
# 201950-SA Ambulance Service

# %%
# def clean_and_extract_organization(df_ga_orig: pd.DataFrame) -> pd.DataFrame:
#     df_ga = df_ga_orig.dropna().copy()
#     df_ga['organization_id_name'] = df_ga['Landing Page'].apply(clean_landing_page_column)
#     df_ga['organization_id'] = df_ga['organization_id_name'].apply(get_organization_id)
#     df_ga['organization_name'] = df_ga['organization_id_name'].apply(get_organization_name)
#     return df_ga[["Landing Page", "organization_id_name","organization_id","organization_name", "Sessions"]]

# %%
# def get_combined_data(sacommunity_url, df_org_id_and_session, df_sacommunity, df_google_analytics):
#     results = []
#     for index, row in df_org_id_and_session.iterrows():
#         org_id = index
        
#         session_count = row["Sessions"]
        
#         # organization name from sa-community file
#         org_names_sa_community = df_sacommunity[df_sacommunity['ID_19'] == org_id]["Org_name"].values
#         organization_name_sa_community = ''
#         is_record_available_in_sacommunity_db = False
#         if len(org_names_sa_community) > 0:
#             organization_name_sa_community = org_names_sa_community[0]
#             is_record_available_in_sacommunity_db = True
       
#         # organization name from google analytics file
#         org_names_google = df_google_analytics[df_google_analytics["organization_id"] == org_id]["organization_name"].values
#         organization_name_google = ''
#         if len(org_names_google) > 0:
#             organization_name_google = org_names_google[0]

#         landing_page = sacommunity_url + df_google_analytics[df_google_analytics["organization_id"] == org_id]["Landing Page"].values[0]
#         results.append({
#             'org_id': org_id,
#             'landing_page': landing_page,
#             'sessions_count': session_count,
#             'organization_name_sa_community': organization_name_sa_community,
#             'organization_name_google': organization_name_google,
#             'is_record_available_in_sacommunity_db': is_record_available_in_sacommunity_db,
#         })

#     return pd.DataFrame(results)

# %%
# def data_preprocessing(google_analytics_df, sa_community_df):
#     df_google_analytics_cleaned = clean_and_extract_organization(google_analytics_df)
#     df_grp_org_id = df_google_analytics_cleaned.groupby(by=['organization_id']).sum("Sessions")

#     # df_sacommunity_data = pd.read_csv(sa_community_data_file_path)

#     # print('google analytics data')
#     # display(df_google_analytics_cleaned.head())

#     # print('SA community data')
#     # display(sa_community_df.head())

#     return get_combined_data(df_grp_org_id, sa_community_df, df_google_analytics_cleaned)

# %%
# # lp = pd.read_excel('./data/Burnside Council Landing page 2021-2022.xlsx',sheet_name='Dataset1')
# lp = read_landing_page_data(landing_page_file_path)
# lp.head()

# %%
# landing_page_file_path = './data/Burnside Council Landing page 2021-2022.xlsx'
# sacommunity.data.gov.au_export.csv
# sa_community_data_file_path = './data/Burnside Council-cu_export_2023-08-16_Data.Gov.au_export.csv'

# data_df = data_preprocessing(landing_page_file_path, sa_community_data_file_path)
# data_df

# %%
# these records are problematic, they are found in google analytics, but not in sacommunity council based export 
# problematic_data = data_df[data_df["is_record_available_in_sacommunity_db"] == False]
# # TODO: add landing page in this df
# problematic_data

# %%
# problematic_data.to_csv("./data/problematic_data.csv")

# %%
# from selenium import webdriver
# from selenium.webdriver.common.by import By

# from selenium import webdriver
# from chromedriver_py import binary_path # this will get you the path variable



# # # deprecated but works in older selenium versions
# # # driver = webdriver.Chrome(executable_path=binary_path)
# # driver.get("http://www.python.org")
# # assert "Python" in driver.title

# def test_eight_components():
#     driver = webdriver.Chrome(executable_path=binary_path)

#     driver.get("https://www.selenium.dev/selenium/web/web-form.html")

#     title = driver.title
#     assert title == "Web form"

#     driver.implicitly_wait(10) # 0.5

#     text_box = driver.find_element(by=By.NAME, value="my-text")
#     submit_button = driver.find_element(by=By.CSS_SELECTOR, value="button")

#     text_box.send_keys("Selenium")
#     submit_button.click()

#     message = driver.find_element(by=By.ID, value="message")
#     value = message.text
#     assert value == "Received!"

#     driver.quit()

# test_eight_components()

# %%
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from chromedriver_py import binary_path # this will get you the path variable

# async def get_text_by_xpath(driver, x_path):
#     return await driver.find_element(by=By.CSS_SELECTOR, value=x_path).text

# driver = webdriver.Chrome(executable_path=binary_path)

# driver.get("https://lga-sa.maps.arcgis.com/apps/instant/lookup/index.html?appid=db6cce7b773746b4a1d4ce544435f9da&find=130%20L%27Estrange%20Street%2C%20Glenunga")

# # driver.implicitly_wait(60)
# print('page source ', driver.page_source)
# # //*[@id="FindMyCouncil_944448"]/div/div/div/div/div/div/table/tbody/tr[1]/th
# # h1 = driver.find_element(by=By.XPATH, value='//*[@id="FindMyCouncil_944448"]/div/div/div/div/div/div/table/tbody/tr[1]/th')
# # v1 = driver.find_element(by=By.XPATH, value='//*[@id="FindMyCouncil_944448"]/div/div/div/div/div/div/table/tbody/tr[1]/td')
# # h2 = driver.find_element(by=By.XPATH, value='//*[@id="FindMyCouncil_944448"]/div/div/div/div/div/div/table/tbody/tr[2]/th')
# # v2 = driver.find_element(by=By.XPATH, value='//*[@id="FindMyCouncil_944448"]/div/div/div/div/div/div/table/tbody/tr[2]/td')
# # h3 = driver.find_element(by=By.XPATH, value='//*[@id="FindMyCouncil_944448"]/div/div/div/div/div/div/table/tbody/tr[3]/th')
# # v3 = driver.find_element(by=By.XPATH, value='//*[@id="FindMyCouncil_944448"]/div/div/div/div/div/div/table/tbody/tr[3]/td')
# print('getting element for council')
# print(await get_text_by_xpath(driver, '#FindMyCouncil_944448 > div > div > div > div > div > div > table > tbody > tr:nth-child(1) > th'))
# print()
# # print(v1.text)

# driver.quit
